# %% [markdown]
# ### CatBoost를 이용한 Classifier

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
os.chdir(r'C:\Users\tagkd\Desktop\인공지능 연습\Untitled Folder')

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
df= iris.corr()

# %%
fig = plt.figure(figsize=(12,6))
ax = sns.heatmap(df)
plt.title('df.corr()')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
cols = list(iris.columns)

# %%
data = cols[:-1]
target = cols[-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(iris[data],iris[target],test_size=0.3)

# %%
from catboost import CatBoostClassifier

# %%
model = CatBoostClassifier()
model.fit(X_train,y_train)
model
# Out:
# Learning rate set to 0.070535
# 0:	learn: 1.0085369	total: 136ms	remaining: 2m 16s
# 1:	learn: 0.9491832	total: 139ms	remaining: 1m 9s
# 2:	learn: 0.8895304	total: 143ms	remaining: 47.4s
# 3:	learn: 0.8296444	total: 146ms	remaining: 36.3s
# 4:	learn: 0.7774509	total: 149ms	remaining: 29.7s
# 5:	learn: 0.7313201	total: 152ms	remaining: 25.3s
# 6:	learn: 0.6944641	total: 156ms	remaining: 22.1s
# 7:	learn: 0.6617242	total: 159ms	remaining: 19.7s
# 8:	learn: 0.6235570	total: 162ms	remaining: 17.9s
# 9:	learn: 0.5909000	total: 177ms	remaining: 17.5s
# 10:	learn: 0.5612041	total: 181ms	remaining: 16.3s
# 11:	learn: 0.5358313	total: 185ms	remaining: 15.2s
# 12:	learn: 0.5082850	total: 189ms	remaining: 14.3s
# 13:	learn: 0.4810315	total: 192ms	remaining: 13.6s
# 14:	learn: 0.4567458	total: 196ms	remaining: 12.9s
# 15:	learn: 0.4329275	total: 200ms	remaining: 12.3s
# 16:	learn: 0.4122023	total: 204ms	remaining: 11.8s
# 17:	learn: 0.3912723	total: 207ms	remaining: 11.3s
# ...

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
y_pred = model.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.9111111111111111

# %%
con_mat = confusion_matrix(y_test,y_pred)
print(con_mat)
# Out:
# [[12  0  0]
#  [ 0 14  4]
#  [ 0  0 15]]

# %%
report = classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        12
#   versicolor       1.00      0.78      0.88        18
#    virginica       0.79      1.00      0.88        15
#
#     accuracy                           0.91        45
#    macro avg       0.93      0.93      0.92        45
# weighted avg       0.93      0.91      0.91        45

# %%
round(acc,2)
# Out:
# 0.91

# %% [markdown]
# ### CatBoost를 이용한 Regressor

# %%
from sklearn.datasets import load_boston
from catboost import CatBoostRegressor

# %%
boston = load_boston()

# %%
boston.data.shape
# Out:
# (506, 13)

# %%
boston.target.shape
# Out:
# (506,)

# %%
X=boston.data
y=boston.target

# %%
cols = boston.feature_names
cols
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
df = pd.DataFrame( X,columns = boston.feature_names)
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
model = CatBoostRegressor()
model.fit(X_train,y_train)
model
# Out:
# Learning rate set to 0.03284
# 0:	learn: 9.1502583	total: 5.57ms	remaining: 5.57s
# 1:	learn: 8.9620677	total: 10.6ms	remaining: 5.3s
# 2:	learn: 8.7853709	total: 17.7ms	remaining: 5.87s
# 3:	learn: 8.6310513	total: 22.4ms	remaining: 5.57s
# 4:	learn: 8.4872449	total: 25.1ms	remaining: 5s
# 5:	learn: 8.3606941	total: 27.8ms	remaining: 4.61s
# 6:	learn: 8.2120370	total: 31.2ms	remaining: 4.43s
# 7:	learn: 8.0655182	total: 33.8ms	remaining: 4.19s
# 8:	learn: 7.9194781	total: 36.8ms	remaining: 4.05s
# 9:	learn: 7.7782582	total: 39.8ms	remaining: 3.94s
# 10:	learn: 7.6420130	total: 43.2ms	remaining: 3.88s
# 11:	learn: 7.5066377	total: 45.9ms	remaining: 3.78s
# 12:	learn: 7.3695432	total: 49.2ms	remaining: 3.73s
# 13:	learn: 7.2356795	total: 51.9ms	remaining: 3.65s
# 14:	learn: 7.1236958	total: 54.7ms	remaining: 3.59s
# 15:	learn: 7.0008682	total: 57.6ms	remaining: 3.54s
# 16:	learn: 6.8844834	total: 60.7ms	remaining: 3.51s
# 17:	learn: 6.7724452	total: 63.2ms	remaining: 3.45s
# ...

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([20.95750608, 31.34219124, 20.45039604, 11.90424687, 18.64341744,
#        28.90610021, 21.58473434, 15.48166681, 19.75459358, 21.40329593,
#        20.80591191, 20.07779512, 21.18012562, 12.13428977, 37.2922731 ,
#        19.29678638, 23.54764896, 20.91456224, 20.57753503, 24.03134813,
#        23.02268211, 33.3061734 , 16.32143319, 19.10100193, 14.4582263 ,
#        20.17495617, 23.90847051, 14.18351202, 29.19416471, 13.01363727,
#        23.2722953 , 32.32417372, 19.87395067, 22.92200152,  7.73189833,
#         8.64087298, 36.81523346, 24.80746124, 37.66352463, 22.03527223,
#        15.57789986, 41.19736285, 17.3606328 , 36.27265489, 24.35040433,
#        20.0858027 , 18.97547835, 20.79626316, 18.77838297, 24.71760595,
#         6.80356296, 15.79947547, 43.50560982, 26.04125689, 20.8977727 ,
#        17.4126341 , 26.79002437, 28.45161267, 16.27891593, 21.02244901,
#        20.78079414, 25.17608406, 18.85017177, 23.68554028, 35.76582694,
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mae = mean_absolute_error(y_test,y_pred)
mae
# 실제값과 예측값의 차이인 오차들의 절대값 평균
# MSE보다는 특이치에 덜 민감
# Out:
# 1.850591061399725

# %%
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 6.505438169627797

# %% [markdown]
# ### Classifier 실습

# %%
freeze = pd.read_csv('freeze_dataset.csv',encoding='ms949')

# %%
freeze.head()
# Out:
#    동파유무    구경(mm)  일반용  학교용  대중목욕탕용       X좌표       Y좌표    관경(mm)     길이(m)  \
# 0   1.0  0.000000  1.0  0.0     0.0  0.293524  0.223227  0.006341  0.007594
# 1   1.0  0.000000  1.0  0.0     0.0  0.293898  0.223950  0.006341  0.003060
# 2   1.0  0.000000  1.0  0.0     0.0  0.293508  0.226155  0.006341  0.000793
# 3   1.0  0.037433  1.0  0.0     0.0  0.294982  0.222209  0.009756  0.001927
# 4   1.0  0.197861  0.0  0.0     0.0  0.298349  0.220841  0.024390  0.030262
#
#    스테인레스관(STS)  ...  평균기온(°C)_1-10일평균  평균기온(°C)_11-20일평균  평균기온(°C)_21-30일평균  \
# 0          1.0  ...          0.206369           0.230598           0.022059
# 1          0.0  ...          0.209331           0.103559           0.008824
# 2          1.0  ...          0.368551           0.316609           0.260539
# 3          1.0  ...          0.058751           0.173752           0.267647
# 4          0.0  ...          0.082449           0.209343           0.090441
#
# ...

# %%
cols = list(freeze.columns)
cols
# Out:
# ['동파유무',
#  '구경(mm)',
#  '일반용',
#  '학교용',
#  '대중목욕탕용',
#  'X좌표',
#  'Y좌표',
#  '관경(mm)',
#  '길이(m)',
#  '스테인레스관(STS)',
#  '닥타일주철관(DCIP)',
#  '3중구조(HI-3P)',
#  '내충격경질염화비닐관(HIKP)',
#  '내충격경질염화비닐관(HIVP)',
#  '도복장강관(SP)',
#  '폴리에틸렌관(PE)',
#  '경질염화비닐관(PVC)',
#  '주철관(CI)',
#  '아연도강관(GS)',
#  '수도용경질폴리염화비닐관 HIVP(육중벽) ',
#  '강관(ST)',
#  'PVC관(PVC)',
#  '내충격수도관(HINP)',
#  '폴리에틸렌분체라이닝강관(PFP)',
#  '내충격복합폴리머관(ESLON NV)',
#  '강관(CP)',
#  '1달전수도사용',
#  '2달전수도사용',
#  '3달전수도사용',
#  '강수 계속시간(hr)_1-10일평균',
#  '강수 계속시간(hr)_11-20일평균',
#  '강수 계속시간(hr)_21-30일평균',
#  '안개 계속시간(hr)_1-10일평균',
#  '안개 계속시간(hr)_11-20일평균',
#  '안개 계속시간(hr)_21-30일평균',
#  '일 최심적설(cm)_1-10일평균',
#  '일 최심적설(cm)_11-20일평균',
#  '일 최심적설(cm)_21-30일평균',
#  '일강수량(mm)_1-10일평균',
#  '일강수량(mm)_11-20일평균',
#  '일강수량(mm)_21-30일평균',
#  '최고기온(°C)_1-10일평균',
#  '최고기온(°C)_11-20일평균',
#  '최고기온(°C)_21-30일평균',
#  '최고기온(°C)_최근10일영하일수',
#  '최고기온(°C)_최근20일영하일수',
#  '최고기온(°C)_최근10일영하연속일수',
#  '최고기온(°C)_최근20일영하연속일수',
#  '최저 초상온도(°C)_1-10일평균',
# ...

# %%
data = cols[1:]
target=cols[0]

# %%
X_train,X_test,y_train,y_test = train_test_split(freeze[data],freeze[target])

# %%
from catboost import CatBoostClassifier

# %%
model = CatBoostClassifier()
model.fit(X_train,y_train)
# Out:
# Learning rate set to 0.042623
# 0:	learn: 0.6450668	total: 57.5ms	remaining: 57.5s
# 1:	learn: 0.6025372	total: 103ms	remaining: 51.2s
# 2:	learn: 0.5629998	total: 142ms	remaining: 47.2s
# 3:	learn: 0.5250031	total: 182ms	remaining: 45.4s
# 4:	learn: 0.4930683	total: 234ms	remaining: 46.6s
# 5:	learn: 0.4621638	total: 274ms	remaining: 45.5s
# 6:	learn: 0.4367537	total: 309ms	remaining: 43.9s
# 7:	learn: 0.4157385	total: 348ms	remaining: 43.2s
# 8:	learn: 0.3949551	total: 389ms	remaining: 42.8s
# 9:	learn: 0.3764408	total: 421ms	remaining: 41.7s
# 10:	learn: 0.3571007	total: 461ms	remaining: 41.5s
# 11:	learn: 0.3429191	total: 498ms	remaining: 41s
# 12:	learn: 0.3283369	total: 538ms	remaining: 40.8s
# 13:	learn: 0.3173333	total: 577ms	remaining: 40.6s
# 14:	learn: 0.3061867	total: 613ms	remaining: 40.2s
# 15:	learn: 0.2943890	total: 652ms	remaining: 40.1s
# 16:	learn: 0.2843021	total: 689ms	remaining: 39.9s
# 17:	learn: 0.2764548	total: 726ms	remaining: 39.6s
# ...

# %%
y_pred = model.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.9583737733203925

# %%
con_mat = confusion_matrix(y_test,y_pred)
print(con_mat)
# Out:
# [[8453   41]
#  [ 345  434]]

# %%
report = classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98      8494
#          1.0       0.91      0.56      0.69       779
#
#     accuracy                           0.96      9273
#    macro avg       0.94      0.78      0.83      9273
# weighted avg       0.96      0.96      0.95      9273

# %%
import math
rmse = math.sqrt(mse)
rmse
#MSE에 루트를 씌운 값
# 오류 지표를 실제 값과 유사한 단위로 다시 변환하기에 해석이 다소 용이
# Out:
# 2.5505760466270746

# %%
from sklearn.metrics import r2_score
r2_test = r2_score(y_test,y_pred)
r2_test
#결정 계수(R-squared)
#분석기반 예측 성능 평가 -> 상대적인 성능이 어느정도인지 직관적으로 판단
#1에 가까울수록 좋은것
# Out:
# 0.45904909695373586
