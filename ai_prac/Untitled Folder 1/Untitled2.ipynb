# %%
import requests
import lxml.html
import pandas as pd
import time
import re
import string
from konlpy. tag import Kkma
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from wordcloud import WordCloud

from collections import Counter
import numpy as np
kkma = Kkma()
from konlpy. tag import Kkma

from PIL import Image

from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

from bs4 import BeautifulSoup
from selenium.webdriver import ActionChains

# %%
site_url=[]

# %%
driver = webdriver.Chrome("C:\\chromedriver_win32\\chromedriver.exe")

# %%
driver.get('https://kr.trip.com/travel-guide/gwangju-433/tourist-attractions/')

# %%
driver.find_element_by_css_selector("#list > div.gl-poi-list_sortby > div.r > div").click()
time.sleep(0.1)

# %%
driver.find_element_by_xpath('//*[@id="poilist_expo_distance_select_id"]').click()
