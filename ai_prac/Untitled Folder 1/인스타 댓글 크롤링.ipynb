# %%
from selenium import webdriver
import time
from openpyxl import Workbook
import pandas as pd
from selenium.webdriver.common.keys import Keys

# %%
wb = Workbook(write_only=True)
ws = wb.create_sheet()

driver = webdriver.Chrome('C:\\chromedriver_win32\\chromedriver')
driver.get("https://www.instagram.com/")
driver.implicitly_wait(3)

# %%
# 로그인
driver.find_element_by_css_selector("#loginForm > div > div:nth-child(1) > div > label > input").send_keys("tagkdj1@naver.com")
driver.find_element_by_css_selector("#loginForm > div > div:nth-child(2) > div > label > input").send_keys("dlaxodnjs1!")
driver.find_element_by_css_selector("#loginForm > div > div:nth-child(3) > button > div").click()
time.sleep(1)

# 팝업 종료
driver.find_element_by_css_selector("#react-root > section > main > div > div > div > div > button").click()
driver.find_element_by_css_selector("body > div.RnEpo.Yx5HN > div > div > div > div.mt3GC > button.aOOlW.HoLwm").click()
time.sleep(1)

# %%
# 계정 접근
insta_name = driver.find_element_by_css_selector("#react-root > section > nav > div._8MQSO.Cx7Bp > div > div > div.LWmhU._0aCwM > input")
insta_name.send_keys('travelholic_insta')
time.sleep(2)

insta_name.send_keys(Keys.ENTER)
insta_name.send_keys(Keys.ENTER)
time.sleep(2)

# %%
# 첫번째 게시물 클릭
driver.find_elements_by_css_selector('._9AhH0')[1].click()
time.sleep(1)

# %%
# 댓글 플러스 버튼 누르기
for i in range(5):
    try:
        button = driver.find_element_by_css_selector('body > div._2dDPU.CkGkG > div.zZYga > div > article > div.eo2As > div.EtaWk > ul > li > div > button > span')
        time.sleep(2)
    except:
        pass

    if button is not None:
        try:
            driver.find_element_by_css_selector('body > div._2dDPU.CkGkG > div.zZYga > div > article > div.eo2As > div.EtaWk > ul > li > div > button > span').click()
        except:
            break

# 대댓글 버튼 누르기
#buttons = driver.find_elements_by_css_selector('li > ul > li > div > button')

#for button in buttons:
    #button.send_keys(Keys.ENTER)

# %%
# 댓글 내용 추출
id_f = []
rp_f = []

ids  = driver.find_elements_by_css_selector('div.C4VMK > h3 > div > span > a')
replies = driver.find_elements_by_css_selector('div.C7I1f > div.C4VMK > span')

for id, reply in zip(ids, replies):
    id_a = id.text.strip()
    id_f.append(id_a)

    rp_a = reply.text.strip()
    rp_f.append(rp_a)


    data = {"아이디": id_f,
            "코멘트": rp_f}

df = pd.DataFrame(data)
df.to_excel('result.xlsx')

driver.quit()

# %%
df
# Out:
#                       아이디                                                코멘트
# 0               hermes_ws  ✨\n[태극기와 함께 했던 여행지의 순간.jpg]\n\n오늘은 대한민국 광복 76주...
# 1           travelaaalice                              와ㅏ군인들 대박존잘🇰🇷🇰🇷🇰🇷🇰🇷🔥🔥🔥
# 2               u_jinyy_k           @hermes_ws 저 오른쪽 군인 어디서 볼 수 있나여!!ㅋㅋㅋㅋㅋㅋㅋ
# 3              aarequipa_           @hermes_ws 왜 여깃냐고 하려햇는데 댓글에 역시,, 오빠님짱,,🔥
# 4             traveltv.kr                                        남미😢😢😢😢너무 좋지
# 5                inkook97                                   우리나라 국기지만 참 멋있다.
# 6               im_jehoon                                                  😮
# 7                 kd_juny                        사진 두번째 장소 어디인지 아시는분 계신가요?ㅠㅠ
# 8             _designerb_                                      태극기들고 여행가고싶다😢
# 9                  ix_xms                                            정말 멋집니다
# 10            mycall_9012                                       와 마추픽추..대박🔥🔥
# 11  astrologia_en_mi_vida                                                 🇰🇷
# 12          baramdori4536                                                 🙂👍
# 13  dr_seo_hwi_geom_couk_                                             wow...
# 14              ginawwlsk                                           ❤️🙌🙌❤️❤️
# 15       jeongmyeongja233               갑자기 울컼 합니다. 멋집니다👍👍👍 대한민국 화이팅~~!!!👏👏👏
# 16            yesom_juwon                                          대한민국홧팅👏👏👏
# 17              chuunsoon                                    🇰🇷 너무멋진사진입니다 🇰🇷
# 18      lillillil_cxxi_kr                                                  😍
# 19           youngjin1812                                                멋짐👏
# 20         person_over_do                                               멋지네요
# 21           9oo_gram0126  @with_just @hy25gi._.i 머야 다시찾아보니까 국기 안된다는 건 딱히 없네
# 22              n_dahyeon                   @fm_ji.d.hwan0324 하 이걸 했어야 했는데..
# 23               mxnchang                              @jjee_0ng 우와 이거 멋있당ㅎㅎ
# 24                jiiii_0                                    @fe_hwan 전부 남미네
# 25               oh_rrang                                        @rookie.rin
# 26           jiyoung_only                              @joongmin_e_ 거의 너 ㅋㅋㅋ
# 27             ssoooyeong               @mijeong4275 올해한라산.못가겟지?가면이거가져가믄딱인데😍
# 28            saxxhul_9oo                                      @19.96_eu ㅋㅋㅋ
# 29                kd_juny                @lim_dongdongs @2.26_cmj 우리사진운 왜 없음
# 30            _designerb_                                      태극기들고 여행가고싶다😢
# 31                 ix_xms                                            정말 멋집니다
# 32            mycall_9012                                       와 마추픽추..대박🔥🔥
# 33  astrologia_en_mi_vida                                                 🇰🇷
# 34          baramdori4536                                                 🙂👍
# 35  dr_seo_hwi_geom_couk_                                             wow...
# 36              ginawwlsk                                           ❤️🙌🙌❤️❤️
# 37       jeongmyeongja233               갑자기 울컼 합니다. 멋집니다👍👍👍 대한민국 화이팅~~!!!👏👏👏
# 38              zlatjdals                                          대한민국홧팅👏👏👏
# 39            yesom_juwon                                    @hangelnal ㄱ?ㅎㅎ
# 40              chuunsoon                                    🇰🇷 너무멋진사진입니다 🇰🇷
# 41      lillillil_cxxi_kr                                                  😍
# 42            ye_eun._.ee                                                멋짐👏
# 43            hyun__gyomi                                         @rosye.kim
# 44           youngjin1812                            @bogyeong_97 담엔 이케 들고가쟈
# 45          isaacpark6711                                               멋지네요
# 46          eduar_do_hyun                                    이런 나라사랑 참 좋타 ~~
# 47               gugbeomi                           진짜 외국에서 보면 더 벅차오르는 태극기🇰🇷
# 48               gugbeomi                                                 드드
# 49          rosedalia._.3                                                  ?
# 50      hanminkyoung_5464                                                KR!
# 51           babyzakk9412                      태극기부대 때문에\n태극기에 대한 인식이 나빠짐 ㅠㅠ
# 52               jh870921            크, 할때는 이 무슨 고생인가 싶지만 오늘같은날 떡상하기 좋은 프로젝트
# 53                go_pole      @1da0_95 우리 간데 다 있어 나혼자 간 호수 그것도 있는듯 파론호순가 거기
# 54           dear.sophie_                                       태극기는 사랑입니다~~
# 55                kbs1576                                        @l_my94 믓찌다
# 56             hongyeol62                            국경일만 태극기 달지 말고 평소에좀 달아라
