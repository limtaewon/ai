# %%
import requests
import lxml.html
import pandas as pd
import time
import re
import string
from konlpy. tag import Kkma
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from wordcloud import WordCloud

from collections import Counter
import numpy as np
kkma = Kkma()
from konlpy. tag import Kkma

from PIL import Image

# %%
from selenium import webdriver
import time
 
# 크롬 웹브라우저 실행
path = "C:\\chromedriver_win32\\chromedriver.exe"

# %%
driver = webdriver.Chrome(path)
url_list = []
content_list = ""
text = "제주도애월"

# %%
for i in range(1, 10):  # 1~2페이지까지의 블로그 내용을 읽어옴
    url = 'https://section.blog.naver.com/Search/Post.naver?pageNo='+ str(i) + '&rangeType=ALL&orderBy=sim&keyword=' + text
    driver.get(url)
    time.sleep(0.5)
 
    for j in range(1, 8): # 각 블로그 주소 저장
        titles = driver.find_element_by_xpath('//*[@id="content"]/section/div[2]/div['+str(j)+']/div/div[1]/div[1]/a[1]')
        title = titles.get_attribute('href')
        url_list.append(title)
 
print("url 수집 끝, 해당 url 데이터 크롤링")
 
for url in url_list: # 수집한 url 만큼 반복
    driver.get(url) # 해당 url로 이동
 
    driver.switch_to.frame('mainFrame')
    overlays = ".se-component.se-text.se-l-default" # 내용 크롤링
    contents = driver.find_elements_by_css_selector(overlays)
 
    for content in contents:
        content_list = content_list + content.text # content_list 라는 값에 + 하면서 점점 누적
# Out:
# url 수집 끝, 해당 url 데이터 크롤링

# %%
content_list
# Out:
# '지난 주말에 친구들과 제주도로 여행을 갔는데요.\n힐링이라는 테마로 미리 점 찍어두었던 제주도 애월 카페에서 족욕과 커피 한 잔의 여유를 동시에 즐길 수 있던 곳이라 소개해드려요.주소 : 제주특별자치도 제주시 애월읍 애월해안로 230 고내리 1158\n전화번호 : 064-799-1152\n영업시간 : 토요일 12:00-20:00\n휴무일 : 매주 수요일 휴무\n메인메뉴 : 족욕&아메리카노 (HOT) 8,000원/족욕&아메리카노(ICE) 9,000원이날 다녀온 1158족욕 카페는 올레길 15코스 종점에 위치해 있어요.\n고내포구 바로 옆이라서 아름다운 바다 뷰를 감상하기에도 좋은 접근성이었어요.고내리 포구로 통유리로 되어 있는 최고의 바다전망이었는데요.\n내부가 훤히 들여다 보이는 인테리어까지도 세심하게 신경을 쓴 거 같았어요.가게 앞으로는 넓은 공간으로 전용 주차장도 완비되어 있었어요.\n갓길에 편하게 파킹을 할 수 있어서 초보운전자인 저도 한 번에 주차 성공했어요.파킹을 마치고 제주도 애월 카페 안으로 들어가 보았어요.\n선결제를 한 후에 음식이 세팅되는 시스템이었으며 좌식 테이블로 꾸며져 있었어요.선주문을 위해서 족욕&음료 메뉴판을 정독했어요.\n아메리카노와 족욕까지 1만 원도 안 넘는 금액대로 가성비가 좋아 찾아온 보람이 느껴졌어요.주문을 마치고 내부를 둘러보니 아기자기한 소품들도 판매 중이었는데요.\n가격대도 저렴하고 제주스러움이 물씬 풍겨 구경하느라 시간 가는 줄 몰랐어요.자리를 잡으러 안쪽으로 들어가 보니 창가석으로 테이블 바처럼 진열되어 있었는데요.\n가만히 앉아서 파도 소리 듣는 거만으로도 큰 힐링이 될 거 같았어요.2층으로 올라가는 길목에도 귀여운 그림으로 꾸며져 있었는데요.\n개성 있는 문구로 제주도 애월 카페 사장님 센스가 느껴졌어요.벽면에는 족욕의 효능에 대해서 안내되어 있어 읽어보았어요.