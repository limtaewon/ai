# %%
# !pip install selenium

# %%
from selenium import webdriver
import time
from openpyxl import Workbook
import pandas as pd
from selenium.webdriver.common.keys import Keys
import time
import re

# %%
from selenium import webdriver

options = webdriver.ChromeOptions()
options.add_argument("--start-maximized"); #브라우저 크기 확장
    
browser = webdriver.Chrome('C:\\chromedriver_win32\\chromedriver', options=options)
#브라우저를 연다

# %%
browser.get('https://www.instagram.com/accounts/login/?source=auth_switcher')
browser.implicitly_wait(5)

# %%
browser.find_element_by_xpath('//*[@id="loginForm"]/div/div[1]/div/label/input').send_keys('tagkdj1@naver.com')
browser.find_element_by_xpath('//*[@id="loginForm"]/div/div[2]/div/label/input').send_keys('dlaxodnjs1!')
browser.implicitly_wait(5)

# %%
browser.find_element_by_xpath('//*[@id="loginForm"]/div/div[3]/button/div').click()
browser.implicitly_wait(5)

# %%
browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/div/div/button').click()
browser.implicitly_wait(5)

# %%
browser.find_element_by_xpath('/html/body/div[5]/div/div/div/div[3]/button[2]').click()
browser.implicitly_wait(5)

# %%
browser.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input').send_keys('여행')

# %%
browser.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input').send_keys(Keys.RETURN)

# %%
browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div[3]/article/div[1]/div/div[1]/div[1]/a/div[2]').click()
browser.implicitly_wait(5)
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-54-7f6163ca8908> in <module>
# ----> 1 browser.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div[3]/article/div[1]/div/div[1]/div[1]/a/div[2]').click()
#       2 browser.implicitly_wait(5)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ...

# %%
trs = browser.find_elements_by_xpath('/html/body/div[6]/div[2]/div/article/div[3]/div[1]/ul')
df_list = []
for tr in trs:
    for i in range(1, ):
        df = pd.DataFrame({ 
                'NO': [tr.find_element_by_xpath('ul[' + str(i) + ']/div/li/div/div[1]/div[2]/span').text],
            })
        df_list.append(df)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-19-79fd3169fc2e> in <module>
#       4     for i in range(1, ):
#       5         df = pd.DataFrame({
# ----> 6                 'NO': [tr.find_element_by_xpath('ul[' + str(i) + ']/div/li/div/div[1]/div[2]/span').text],
#       7             })
#       8         df_list.append(df)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_xpath(self, xpath)
#     349             element = element.find_element_by_xpath('//div/td[1]')
#     350         """
# --> 351         return self.find_element(by=By.XPATH, value=xpath)
#     352
#     353     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     656                 value = '[name="%s"]' % value
#     657
# ...

# %%
df_list
# Out:
# [                                                  NO
#  0  좋은기회로 소소하게 할머니와의 제주도에서의 이야기를 전달할 수 있어서 좋았습니다 !...,
#                                                    NO
#  0  애교많은 예쁜아들,손자네요.남은 인생 할머니는 얼마나 행복할까요~바르게 키우신 할머...,
#                               NO
#  0  ❤️❤️❤️❤️빵근이 할모니 사랑해요❤️❤️❤️❤️,
#                  NO
#  0  나도 할무니 보고싶다,,ㅠㅠ,
#                         NO
#  0  너무 마음 따뜻한 이야기에요🥺❤️😍❤️😍,
#              NO
#  0  따수워..,.,.❤️,
#              NO
#  0  오래오래 건강하세요💙,
#                       NO
#  0  너무 보기 좋아요🙏🏻🙏🏻행복하세요😍😍,
#              NO
#  0  외할머니 보고싶다..,
#         NO
#  0  멋지다 👏👏,
#                 NO
#  0  ❤️❤️❤️❤️❤️❤️❤️,
#                             NO
#  0  따뜻하고 또 따뜻한 이야기\n할머니 보고싶다ㅠㅠ]

# %%
a = str(df_list)

# %%
punc = '[!"#$%&\'()*+,-./:;<=>?[\]^_`{|}~“”·]'
b = re.sub(punc,"",a)
b = b.replace("\\n","")
b = b.replace("NO\n0 ","")

# %%
b = b.replace("          ","")

# %%
b
