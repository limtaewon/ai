# %%
import re

# %% [markdown]
# ##### . : 한개의 임의의 문자를 나타냅니다. (줄바꿈 문자인 \n는 제외)
# ##### ? : 앞의 문자가 존재할 수도 있고, 존재하지 않을수도 있습니다 (문자가 0개 또는 1개)
# ##### * : 앞의 문자가 무한개로 존재할 수도 있고, 존재하지 않을수도 있습니다(문자가 0개이상)
# ##### + : 앞의 문자가 최소 한 개 이상 존재합니다 (문자가 1개 이상)
# ##### ^ : 뒤의 문자로 문자열이 시작됩니다.
# ##### shift4 : 앞의 문자로 문자열이 끝납니다.
# ##### {숫자} : 숫자만큼 반복합니다.
# ##### {숫자1,숫자2} : 숫자1이상 숫자2이하만큼 반복합니다. ?*+를 대체할수 있습니다.
# ##### {숫자,} : 숫자 이상만큼 반복합니다
# ##### [] : 대괄호 안의 문자들 중 한 개의 문자와 매치합니다 [amk]라고 한다면 a 또는 m 또는 k 중 하나라도 존재하면 매치를 의미합니다 [a-z]와 같이 범위를 지정할 수도 있습니다. [a-zA-Z]는 알파벳 저네를 의미하는 범위이며, 문자열에 알파벳이 존재하면 매치를 의미합니다
# ##### [^문자] : 해당 문자를 제외한 문자를 매치합니다.
# ##### | : A|B와 같이 쓰이며 A또는 B를 의미합니다
#
#
# ##### \\ : 역 슬래쉬 문자 자체를 의미합니다.
# ##### \d : 모든 숫자를 의미합니다. [0-9]와 같은 의미입니다.
# ##### \D : 숫자를 제외한 모든 문자를 의미합니다. [^0-9]와 같은 의미입니다.
# ##### \s : 공백을 의미합니다. [\t\n\r\f\v]와 같은 의미입니다.
# ##### \S : 공백을 제외한 문자를 의미합니다. [^\t\n\r\f\v]와 같은 의미입니다.
# ##### \w : 문자 또는 숫자를 의미합니다.[a-zA-Z0-9]와 같은 의미입니다.
# ##### \W : 문자 또는 숫자가 아닌 문자를 의미합니다.[^a-zA-Z0-9]와 같은 의미입니다.

# %%
r = re.compile('a.c')
r.search('abc')
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
r = re.compile("ab?c")
r.search("ac") 
# a와 c 사이에 b가 있거나 없으면 매치
# Out:
# <re.Match object; span=(0, 2), match='ac'>

# %%
r = re.compile("ab*c")
r.search("abbc")
# a와 c 사이에 b가0개이상 있다면 매치
# Out:
# <re.Match object; span=(0, 4), match='abbc'>

# %%
r = re.compile('ab+c')
r.search('abc')
# a와 c사이에 b가 1개이상 있다면 매치
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
r = re.compile('^a')
r.search('abcefsk')
# ^뒤에 있는 문자로 시작하면 매치
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
r = re.compile('ab{2}c')
r.search('abbc')
# a와c사이에 b가2번({2}) 있다면 매치
# Out:
# <re.Match object; span=(0, 4), match='abbc'>

# %%
r = re.compile('ab{2,8}c')
r.search('abbbbbbbbc')
# a와c사이에 b가 2~8개라면 매치
# Out:
# <re.Match object; span=(0, 10), match='abbbbbbbbc'>

# %%
r = re.compile('ab{2,}c')
r.search('abbbbbbbbbbbbbbc')
# a와 c사이에 b가 2개이상이라면 매치
# Out:
# <re.Match object; span=(0, 16), match='abbbbbbbbbbbbbbc'>

# %%
r = re.compile("[abc]")
r.search('cream')
#[]안에 있는 문자가 문자열에 있다면 매치
# Out:
# <re.Match object; span=(0, 1), match='c'>

# %%
r = re.compile('[^abc]')
r.search('drum')
# ^이 붙으면 조건의 반대와 매치
# Out:
# <re.Match object; span=(0, 1), match='d'>

# %%
r = re.compile('.ab')
r.search('kkkkab')
# Out:
# <re.Match object; span=(3, 6), match='kab'>

# %%
r.match('kkkkab')
# match는 조건이 문자열의 시작에서 패턴이 일치해야한다.
# kabkk

# %%
text = '사과 딸기 수박 멜론 바나나'
re.split(' ',text)
#split은 함수안에 적은 조건으로 분리하여 리스트화 시켜준다.
# Out:
# ['사과', '딸기', '수박', '멜론', '바나나']

# %%
text = """이름 : 임태원
전화번호 : 010-4358-0106
나이 : 24
성별 : 남"""
re.findall("\w*\w",text)
# findall은 전체 텍스트에서 조건에 매치되는 문자열을 리스트로 리턴한다.
# Out:
# ['이름', '임태원', '전화번호', '010', '4358', '0106', '나이', '24', '성별', '남']

# %%
text="Regular expression : A regular expression, regex or regexp[1] (sometimes called a rational expression)[2][3] is, in theoretical computer science and formal language theory, a sequence of characters that define a search pattern."
re.sub('[^a-zA-Z0-9가-힣]',' ',text)
# 알파벳이 아니라면 공백으로 대체됨
# sub은 정규표현식 패턴과 일치하는 문자열을 찾아 다른 문자열로 대체할 수 있다.
# Out:
# 'Regular expression   A regular expression  regex or regexp 1   sometimes called a rational expression  2  3  is  in theoretical computer science and formal language theory  a sequence of characters that define a search pattern '
